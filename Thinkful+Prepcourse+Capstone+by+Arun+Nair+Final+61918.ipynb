# %% [markdown]
# # Thinkful Prepcourse Capstone
# ## Global Agriculture Statistics
# #### Arun Nair

# %% [markdown]
# ##### FOREWARD
# I would like to thank my mentor Antonio Rueda Toicen, without whom I would not have been able to successfully understand the concepts necessary to write this Capstone.

# %% [markdown]
# **The goal of this capstone is to:**
# 1. look at the agricultural production of 200 countries in the world, and then compare the top 5 crop producing nations.
# 2. compare the bottom 5 crop producing nations.
# 3. perform a t-test from sample of top 5 vs. bottom 5.

# %% [markdown]
# ## Description of the FAO Dataset

# %% [markdown]
# A detailed description of the columns in the Food and Agricultural Organization of the United Nations dataset can be found here:
#
# [FAO Definitions](http://www.fao.org/faostat/en/#definitions
# )
#
#
# Main Characteristics of the Data can be found with following link:
#
# [Metadata](http://www.fao.org/faostat/en/#data/QC/metadata
# )
#
# A further, and more interactive source can be found [here](http://www.fao.org/faostat/en/#data/QC/visualize).
#
#
# The data has been collected throught the years 1961 to 2007.

# %% [markdown]
# ### Other Terms and Values
#
# 1. Value: expressed in ["International Dollars"](https://en.wikipedia.org/wiki/Geary–Khamis_dollar), a unit representing the value of the US dollar at a given point of time.
#
# 2. PIN: [Production Index Number](http://www.fao.org/waicent/faostat/agricult/pinelint-e.htm)

# %% [markdown]
# #### Libraries
# We begin by loading the necessary libraries

# %%
import numpy as np
import pandas as pd
import scipy as scipy
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.cbook as cbook
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv("fao_data_production_indices_data.csv", low_memory=False)
df
# Out:
#        country_or_area                                       element_code  \
# 0          Afghanistan                                                152
# 1          Afghanistan                                                152
# 2          Afghanistan                                                152
# 3          Afghanistan                                                152
# 4          Afghanistan                                                152
# 5          Afghanistan                                                152
# 6          Afghanistan                                                152
# 7          Afghanistan                                                152
# 8          Afghanistan                                                152
# 9          Afghanistan                                                152
# 10         Afghanistan                                                152
# 11         Afghanistan                                                152
# 12         Afghanistan                                                152
# 13         Afghanistan                                                152
# 14         Afghanistan                                                152
# 15         Afghanistan                                                152
# 16         Afghanistan                                                152
# 17         Afghanistan                                                152
# 18         Afghanistan                                                152
# 19         Afghanistan                                                152
# 20         Afghanistan                                                152
# 21         Afghanistan                                                152
# 22         Afghanistan                                                152
# 23         Afghanistan                                                152
# 24         Afghanistan                                                152
# 25         Afghanistan                                                152
# 26         Afghanistan                                                152
# 27         Afghanistan                                                152
# 28         Afghanistan                                                152
# 29         Afghanistan                                                152
# ...                ...                                                ...
# 311604        Zimbabwe                                                438
# 311605        Zimbabwe                                                438
# 311606        Zimbabwe                                                438
# 311607        Zimbabwe                                                438
# 311608        Zimbabwe                                                438
# 311609        Zimbabwe                                                438
# 311610        Zimbabwe                                                438
# 311611        Zimbabwe                                                438
# 311612        Zimbabwe                                                438
# 311613        Zimbabwe                                                438
# 311614        Zimbabwe                                                438
# 311615        Zimbabwe                                                438
# 311616        Zimbabwe                                                438
# 311617        Zimbabwe                                                438
# 311618        Zimbabwe                                                438
# 311619        Zimbabwe                                                438
# 311620        Zimbabwe                                                438
# 311621        Zimbabwe                                                438
# 311622        Zimbabwe                                                438
# 311623        Zimbabwe                                                438
# 311624        Zimbabwe                                                438
# 311625        Zimbabwe                                                438
# 311626        Zimbabwe                                                438
# 311627        Zimbabwe                                                438
# 311628        Zimbabwe                                                438
# 311629        Zimbabwe                                                438
# 311630        Zimbabwe                                                438
# 311631        Zimbabwe                                                438
# 311632         fnSeqID                                           Footnote
# 311633              A   May include official, semi-official or estimat...
#
#                                      element    year         unit      value  \
# 0       Gross Production 1999-2001 (1000 I$)  2007.0  1000 Int. $  2486910.0
# 1       Gross Production 1999-2001 (1000 I$)  2006.0  1000 Int. $  2278516.0
# 2       Gross Production 1999-2001 (1000 I$)  2005.0  1000 Int. $  2524097.0
# 3       Gross Production 1999-2001 (1000 I$)  2004.0  1000 Int. $  2226346.0
# 4       Gross Production 1999-2001 (1000 I$)  2003.0  1000 Int. $  2289434.0
# 5       Gross Production 1999-2001 (1000 I$)  2002.0  1000 Int. $  2216530.0
# 6       Gross Production 1999-2001 (1000 I$)  2001.0  1000 Int. $  1863022.0
# 7       Gross Production 1999-2001 (1000 I$)  2000.0  1000 Int. $  1935142.0
# 8       Gross Production 1999-2001 (1000 I$)  1999.0  1000 Int. $  2345362.0
# 9       Gross Production 1999-2001 (1000 I$)  1998.0  1000 Int. $  2373424.0
# 10      Gross Production 1999-2001 (1000 I$)  1997.0  1000 Int. $  2251692.0
# 11      Gross Production 1999-2001 (1000 I$)  1996.0  1000 Int. $  2078803.0
# 12      Gross Production 1999-2001 (1000 I$)  1995.0  1000 Int. $  1942334.0
# 13      Gross Production 1999-2001 (1000 I$)  1994.0  1000 Int. $  1857878.0
# 14      Gross Production 1999-2001 (1000 I$)  1993.0  1000 Int. $  1735804.0
# 15      Gross Production 1999-2001 (1000 I$)  1992.0  1000 Int. $  1613963.0
# 16      Gross Production 1999-2001 (1000 I$)  1991.0  1000 Int. $  1661747.0
# 17      Gross Production 1999-2001 (1000 I$)  1990.0  1000 Int. $  1618635.0
# 18      Gross Production 1999-2001 (1000 I$)  1989.0  1000 Int. $  1509873.0
# 19      Gross Production 1999-2001 (1000 I$)  1988.0  1000 Int. $  1532319.0
# 20      Gross Production 1999-2001 (1000 I$)  1987.0  1000 Int. $  1562225.0
# 21      Gross Production 1999-2001 (1000 I$)  1986.0  1000 Int. $  1500417.0
# 22      Gross Production 1999-2001 (1000 I$)  1985.0  1000 Int. $  1656288.0
# 23      Gross Production 1999-2001 (1000 I$)  1984.0  1000 Int. $  1775966.0
# 24      Gross Production 1999-2001 (1000 I$)  1983.0  1000 Int. $  1841872.0
# 25      Gross Production 1999-2001 (1000 I$)  1982.0  1000 Int. $  1884044.0
# 26      Gross Production 1999-2001 (1000 I$)  1981.0  1000 Int. $  1916415.0
# 27      Gross Production 1999-2001 (1000 I$)  1980.0  1000 Int. $  1928668.0
# 28      Gross Production 1999-2001 (1000 I$)  1979.0  1000 Int. $  1953669.0
# 29      Gross Production 1999-2001 (1000 I$)  1978.0  1000 Int. $  1990109.0
# ...                                      ...     ...          ...        ...
# 311604   Net per capita PIN (base 1999-2001)  1988.0       Int. $       90.0
# 311605   Net per capita PIN (base 1999-2001)  1987.0       Int. $       85.0
# 311606   Net per capita PIN (base 1999-2001)  1986.0       Int. $       88.0
# 311607   Net per capita PIN (base 1999-2001)  1985.0       Int. $       91.0
# 311608   Net per capita PIN (base 1999-2001)  1984.0       Int. $       97.0
# 311609   Net per capita PIN (base 1999-2001)  1983.0       Int. $       72.0
# 311610   Net per capita PIN (base 1999-2001)  1982.0       Int. $       69.0
# 311611   Net per capita PIN (base 1999-2001)  1981.0       Int. $       66.0
# 311612   Net per capita PIN (base 1999-2001)  1980.0       Int. $       96.0
# 311613   Net per capita PIN (base 1999-2001)  1979.0       Int. $       91.0
# 311614   Net per capita PIN (base 1999-2001)  1978.0       Int. $       81.0
# 311615   Net per capita PIN (base 1999-2001)  1977.0       Int. $       79.0
# 311616   Net per capita PIN (base 1999-2001)  1976.0       Int. $       98.0
# 311617   Net per capita PIN (base 1999-2001)  1975.0       Int. $       90.0
# 311618   Net per capita PIN (base 1999-2001)  1974.0       Int. $       88.0
# 311619   Net per capita PIN (base 1999-2001)  1973.0       Int. $       78.0
# 311620   Net per capita PIN (base 1999-2001)  1972.0       Int. $       82.0
# 311621   Net per capita PIN (base 1999-2001)  1971.0       Int. $       79.0
# 311622   Net per capita PIN (base 1999-2001)  1970.0       Int. $       65.0
# 311623   Net per capita PIN (base 1999-2001)  1969.0       Int. $      125.0
# 311624   Net per capita PIN (base 1999-2001)  1968.0       Int. $       59.0
# 311625   Net per capita PIN (base 1999-2001)  1967.0       Int. $       83.0
# 311626   Net per capita PIN (base 1999-2001)  1966.0       Int. $      105.0
# 311627   Net per capita PIN (base 1999-2001)  1965.0       Int. $      107.0
# 311628   Net per capita PIN (base 1999-2001)  1964.0       Int. $      139.0
# 311629   Net per capita PIN (base 1999-2001)  1963.0       Int. $       81.0
# 311630   Net per capita PIN (base 1999-2001)  1962.0       Int. $       98.0
# 311631   Net per capita PIN (base 1999-2001)  1961.0       Int. $      103.0
# 311632                                   NaN     NaN          NaN        NaN
# 311633                                   NaN     NaN          NaN        NaN
#
#        value_footnotes         category
# 0                   A   agriculture_pin
# 1                   A   agriculture_pin
# 2                   A   agriculture_pin
# 3                   A   agriculture_pin
# 4                   A   agriculture_pin
# 5                   A   agriculture_pin
# 6                   A   agriculture_pin
# 7                   A   agriculture_pin
# 8                   A   agriculture_pin
# 9                   A   agriculture_pin
# 10                  A   agriculture_pin
# 11                  A   agriculture_pin
# 12                  A   agriculture_pin
# 13                  A   agriculture_pin
# 14                  A   agriculture_pin
# 15                  A   agriculture_pin
# 16                  A   agriculture_pin
# 17                  A   agriculture_pin
# 18                  A   agriculture_pin
# 19                  A   agriculture_pin
# 20                  A   agriculture_pin
# 21                  A   agriculture_pin
# 22                  A   agriculture_pin
# 23                  A   agriculture_pin
# 24                  A   agriculture_pin
# 25                  A   agriculture_pin
# 26                  A   agriculture_pin
# 27                  A   agriculture_pin
# 28                  A   agriculture_pin
# 29                  A   agriculture_pin
# ...                ...              ...
# 311604              A      non_food_pin
# 311605              A      non_food_pin
# 311606              A      non_food_pin
# 311607              A      non_food_pin
# 311608              A      non_food_pin
# 311609              A      non_food_pin
# 311610              A      non_food_pin
# 311611              A      non_food_pin
# 311612              A      non_food_pin
# 311613              A      non_food_pin
# 311614              A      non_food_pin
# 311615              A      non_food_pin
# 311616              A      non_food_pin
# 311617              A      non_food_pin
# 311618              A      non_food_pin
# 311619              A      non_food_pin
# 311620              A      non_food_pin
# 311621              A      non_food_pin
# 311622              A      non_food_pin
# 311623              A      non_food_pin
# 311624              A      non_food_pin
# 311625              A      non_food_pin
# 311626              A      non_food_pin
# 311627              A      non_food_pin
# 311628              A      non_food_pin
# 311629              A      non_food_pin
# 311630              A      non_food_pin
# 311631              A      non_food_pin
# 311632             NaN     non_food_pin
# 311633             NaN     non_food_pin
#
# [311634 rows x 8 columns]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# For the purpose of this capstone, we will only be looking at the following values:
# 1. Country
# 2. Year
# 3. Value
#
# This is done so that we can get a idea of the how much production has been yielded by the countries in case, over a span of set years.
#
# We can clean the data by filtering out the columns that contains values or strings that are currently not needed.

# %%
del df['element_code']
del df['value_footnotes']
del df['unit']
df.head()
# Out:
#   country_or_area                               element    year      value  \
# 0     Afghanistan  Gross Production 1999-2001 (1000 I$)  2007.0  2486910.0
# 1     Afghanistan  Gross Production 1999-2001 (1000 I$)  2006.0  2278516.0
# 2     Afghanistan  Gross Production 1999-2001 (1000 I$)  2005.0  2524097.0
# 3     Afghanistan  Gross Production 1999-2001 (1000 I$)  2004.0  2226346.0
# 4     Afghanistan  Gross Production 1999-2001 (1000 I$)  2003.0  2289434.0
#
#           category
# 0  agriculture_pin
# 1  agriculture_pin
# 2  agriculture_pin
# 3  agriculture_pin
# 4  agriculture_pin

# %% [markdown]
# The category column refers to the Production Index Numbers of a particular category. (E.g. agriculture, non food, livestock). All these fall under the agricultural banner, and are hence quite redundant. However, we can still find the different unique categories available, in order to better understand where these **"PINs"** come from.

# %% [markdown]
# Before doing describe, we should drop the aggregates (+)

# %%
df['category'].unique()
# Out:
# array(['agriculture_pin', 'crops_pin', 'food_pin', 'livestock_pin',
#        'non_food_pin'], dtype=object)

# %% [markdown]
# Let us change the column headers for better simplicity and understanding.

# %%
headers = ["Country", "Production", "Year", "Value", "Category"]
df.columns = headers
df.head()
# Out:
#        Country                            Production    Year      Value  \
# 0  Afghanistan  Gross Production 1999-2001 (1000 I$)  2007.0  2486910.0
# 1  Afghanistan  Gross Production 1999-2001 (1000 I$)  2006.0  2278516.0
# 2  Afghanistan  Gross Production 1999-2001 (1000 I$)  2005.0  2524097.0
# 3  Afghanistan  Gross Production 1999-2001 (1000 I$)  2004.0  2226346.0
# 4  Afghanistan  Gross Production 1999-2001 (1000 I$)  2003.0  2289434.0
#
#           Category
# 0  agriculture_pin
# 1  agriculture_pin
# 2  agriculture_pin
# 3  agriculture_pin
# 4  agriculture_pin

# %%
df.shape
# Out:
# (311634, 5)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (311624, 5)

# %%
df.dtypes
#Change dtypes
# Out:
# Country        object
# Production     object
# Year          float64
# Value         float64
# Category       object
# dtype: object

# %%
df[["Value", "Year"]] = df[["Value", "Year"]].astype("int")
df[["Year"]]=df[["Year"]].astype("object")
df.dtypes
# Out:
# Country       object
# Production    object
# Year          object
# Value          int32
# Category      object
# dtype: object

# %%
Country= df.groupby('Country').sum()
Country.sort_values
# Out:
# <bound method DataFrame.sort_values of                                           Value
# Country
# Afghanistan                        5.137305e+08
# Africa +                           2.113607e+10
# Albania                            1.494898e+08
# Algeria                            6.302403e+08
# American Samoa                     6.042080e+05
# Americas +                         7.127633e+10
# Angola                             2.221367e+08
# Antigua and Barbuda                1.443409e+06
# Argentina                          5.393473e+09
# Armenia                            5.125982e+07
# Asia +                             1.180869e+11
# Australia                          3.732254e+09
# Australia and New Zealand +        5.300220e+09
# Austria                            8.952169e+08
# Azerbaijan                         1.304907e+08
# Bahamas                            3.921381e+06
# Bahrain                            4.454597e+06
# Bangladesh                         2.325624e+09
# Barbados                           1.058908e+07
# Belarus                            4.137214e+08
# Belgium                            1.960937e+08
# Belgium-Luxembourg                 9.192507e+08
# Belize                             1.729898e+07
# Benin                              1.863003e+08
# Bermuda                            5.753920e+05
# Bhutan                             2.136648e+07
# Bolivia                            3.194424e+08
# Bosnia and Herzegovina             6.457186e+07
# Botswana                           4.215732e+07
# Brazil                             1.190303e+10
# ...                                         ...
# Togo                               9.815398e+07
# Tokelau                            1.422240e+05
# Tonga                              6.153006e+06
# Trinidad and Tobago                2.898700e+07
# Tunisia                            3.987559e+08
# Turkey                             5.075999e+09
# Turkmenistan                       1.475036e+08
# Tuvalu                             2.020120e+05
# US Virgin Islands                  7.590900e+05
# USSR                               1.752022e+10
# Uganda                             9.027127e+08
# Ukraine                            1.579939e+09
# United Arab Emirates               5.613114e+07
# United Kingdom                     3.835667e+09
# United States of America           3.638058e+10
# Uruguay                            4.954437e+08
# Uzbekistan                         6.003070e+08
# Vanuatu                            1.224189e+07
# Venezuela, Bolivarian Republic of  7.854099e+08
# Viet Nam                           2.237842e+09
# Wallis and Futuna Islands          7.250670e+05
# Western Africa +                   6.504505e+09
# Western Asia +                     7.939921e+09
# Western Europe +                   2.124108e+10
# Western Sahara                     1.172192e+06
# World +                            2.946861e+11
# Yemen                              1.598545e+08
# Yugoslav SFR                       1.269856e+09
# Zambia                             1.436475e+08
# Zimbabwe                           3.227885e+08
#
# [252 rows x 1 columns]>

# %%
df.replace({'Gross Production 1999-2001 (1000 I$)':'Gross Production'}, inplace=True)
df.head()
# Out:
#        Country        Production  Year    Value         Category
# 0  Afghanistan  Gross Production  2007  2486910  agriculture_pin
# 1  Afghanistan  Gross Production  2006  2278516  agriculture_pin
# 2  Afghanistan  Gross Production  2005  2524097  agriculture_pin
# 3  Afghanistan  Gross Production  2004  2226346  agriculture_pin
# 4  Afghanistan  Gross Production  2003  2289434  agriculture_pin

# %%
df.replace({'Net Production 1999-2001 (1000 I$)' : 'Net Production',
            'Gross PIN (base 1999-2001)' : 'Gross PIN',
            'Grs per capita PIN (base 1999-2001)':'Gross Per Capita PIN', 
            'Net PIN (base 1999-2001)':'Net PIN', 
            'Net per capita PIN (base 1999-2001)':'Net Per Capita PIN',
           'Russian Federation' : 'Russia'}, inplace=True)

# %%
list(df)
# Out:
# ['Country', 'Production', 'Year', 'Value', 'Category']

# %%
df.Category.unique()
# Out:
# array(['agriculture_pin', 'crops_pin', 'food_pin', 'livestock_pin',
#        'non_food_pin'], dtype=object)

# %%
df.head()
# Out:
#        Country        Production  Year    Value         Category
# 0  Afghanistan  Gross Production  2007  2486910  agriculture_pin
# 1  Afghanistan  Gross Production  2006  2278516  agriculture_pin
# 2  Afghanistan  Gross Production  2005  2524097  agriculture_pin
# 3  Afghanistan  Gross Production  2004  2226346  agriculture_pin
# 4  Afghanistan  Gross Production  2003  2289434  agriculture_pin

# %%
df1 = df.drop(df[df['Production'] != 'Gross Production'].index)
df2 = df1.drop(df1[df1['Category'] != 'agriculture_pin'].index)
df2.tail()
# Out:
#         Country        Production  Year   Value         Category
# 63856  Zimbabwe  Gross Production  1965  687546  agriculture_pin
# 63857  Zimbabwe  Gross Production  1964  740738  agriculture_pin
# 63858  Zimbabwe  Gross Production  1963  625430  agriculture_pin
# 63859  Zimbabwe  Gross Production  1962  679806  agriculture_pin
# 63860  Zimbabwe  Gross Production  1961  640644  agriculture_pin

# %%
gross_prod = df2[['Country', 'Year', 'Value']]
gross_prod.head()
# Out:
#        Country  Year    Value
# 0  Afghanistan  2007  2486910
# 1  Afghanistan  2006  2278516
# 2  Afghanistan  2005  2524097
# 3  Afghanistan  2004  2226346
# 4  Afghanistan  2003  2289434

# %%
gross_prod2 = gross_prod.pivot(index='Country', columns='Year', values='Value')
gross_prod2.head()
# Out:
# Year                  1961        1962        1963        1964        1965  \
# Country
# Afghanistan      1365296.0   1393857.0   1399596.0   1489104.0   1550441.0
# Africa +        40235510.0  42469530.0  44027500.0  44810030.0  45741720.0
# Albania           254771.0    274898.0    274310.0    301150.0    291325.0
# Algeria          1639496.0   1738226.0   1742950.0   1551149.0   1793427.0
# American Samoa      1750.0      1785.0      2000.0      2005.0      2057.0
#
# Year                  1966        1967        1968        1969        1970  \
# Country
# Afghanistan      1575538.0   1717742.0   1790886.0   1829964.0   1658073.0
# Africa +        45589030.0  48631010.0  49961520.0  52174760.0  54258640.0
# Albania           329062.0    343560.0    343240.0    351221.0    366693.0
# Algeria          1209707.0   1345804.0   1729201.0   1601248.0   1658379.0
# American Samoa      2104.0      1941.0      1875.0      1921.0      1850.0
#
# Year               ...              1998         1999         2000  \
# Country            ...
# Afghanistan        ...         2373424.0    2345362.0    1935142.0
# Africa +           ...       105472200.0  109259900.0  110363900.0
# Albania            ...          706612.0     700072.0     733849.0
# Algeria            ...         3033235.0    3107780.0    2941046.0
# American Samoa     ...            2221.0       1781.0       1872.0
#
# Year                   2001         2002         2003         2004  \
# Country
# Afghanistan       1863022.0    2216530.0    2289434.0    2226346.0
# Africa +        113037800.0  116928400.0  122382000.0  126063000.0
# Albania            747971.0     755188.0     789269.0     819870.0
# Algeria           3215132.0    3269373.0    3863700.0    4211766.0
# American Samoa       2054.0       2126.0       2469.0       2365.0
#
# Year                   2005         2006         2007
# Country
# Afghanistan       2524097.0    2278516.0    2486910.0
# Africa +        130236700.0  135449900.0  130351100.0
# Albania            813707.0     858366.0     824818.0
# Algeria           4221735.0    4404404.0    4225072.0
# American Samoa       2365.0       2403.0       2415.0
#
# [5 rows x 47 columns]

# %%
gross_prod2.columns = gross_prod2.columns.astype(str)
years = list(map(str, range(1961, 2008)))
gap = gross_prod2
gap['Total'] = gap.sum(axis=1)
gap.sort_values(['Total'], ascending=False, axis=0, inplace=True)
gap = gap[years].transpose()
gap.fillna(0, inplace=True)
gap.head()
# Out:
# Country      World +       Asia +     Europe +   Americas +  Eastern Asia +  \
# Year
# 1961     607542000.0  179038900.0  224694200.0  151225800.0      73769500.0
# 1962     627390800.0  184564800.0  231333600.0  155494300.0      76666790.0
# 1963     642877400.0  191333500.0  231958200.0  161601700.0      80440290.0
# 1964     666254900.0  199301800.0  244458600.0  162971000.0      85929400.0
# 1965     678915200.0  203996300.0  244380200.0  170410400.0      92461040.0
#
# Country  European Union +       China  Northern America +  Southern Asia +  \
# Year
# 1961          136224300.0  58340740.0          98065620.0       68169040.0
# 1962          141587400.0  60690860.0         100191400.0       68317880.0
# 1963          144877100.0  63942700.0         104454200.0       70574070.0
# 1964          146292400.0  68462610.0         104573900.0       71804500.0
# 1965          147757200.0  74747900.0         108850500.0       69926900.0
#
# Country  United States of America            ...              Faroe Islands  \
# Year                                         ...
# 1961                   89816580.0            ...                      251.0
# 1962                   90275010.0            ...                      239.0
# 1963                   93700380.0            ...                      269.0
# 1964                   94323650.0            ...                      221.0
# 1965                   97704050.0            ...                      207.0
#
# Country   Niue  Marshall Islands  Greenland  British Virgin Islands  Tuvalu  \
# Year
# 1961     498.0               0.0      430.0                   717.0   473.0
# 1962     571.0               0.0      513.0                   708.0   474.0
# 1963     719.0               0.0      458.0                   598.0   476.0
# 1964     856.0               0.0      665.0                   403.0   513.0
# 1965     760.0               0.0      548.0                   409.0   514.0
#
# Country  Nauru  Tokelau  Cayman Islands  Saint Pierre and Miquelon
# Year
# 1961     184.0    170.0             0.0                        0.0
# 1962     184.0    220.0             0.0                        0.0
# 1963     185.0    112.0             0.0                        0.0
# 1964     191.0    281.0             0.0                        0.0
# 1965     212.0    256.0             0.0                        0.0
#
# [5 rows x 252 columns]

# %% [markdown]
# We have alot of **"+"** fields within the dataset. These represent the aggregate values of countries/regions (e.g. Asia, Europe etc). This would prove to result in making errors with our testing, as both the countries **AND** the aggregates will be included in the calculations. Hence, we will be dropping these values from our dataframe.

# %%
gap_unwant = [col for col in gap.columns if '+' in col]
gap = gap.drop(gap_unwant, axis=1)
gap.head()
# Out:
# Country       China  United States of America       India        USSR  \
# Year
# 1961     58340740.0                89816580.0  50142680.0  72768810.0
# 1962     60690860.0                90275010.0  50015760.0  73961920.0
# 1963     63942700.0                93700380.0  51367730.0  70531000.0
# 1964     68462610.0                94323650.0  52267720.0  81216890.0
# 1965     74747900.0                97704050.0  49498330.0  80941960.0
#
# Country      Brazil      France     Germany       Italy   Argentina  \
# Year
# 1961     16564600.0  23408500.0  22077690.0  18638310.0  11950390.0
# 1962     17344940.0  26654000.0  24241470.0  19289340.0  12519320.0
# 1963     17443010.0  25202710.0  25340780.0  18918070.0  13694660.0
# 1964     17658130.0  25321080.0  24843610.0  19893760.0  12918230.0
# 1965     20367240.0  26780910.0  23988490.0  20564500.0  12247380.0
#
# Country  Indonesia            ...              Faroe Islands   Niue  \
# Year                          ...
# 1961     7383684.0            ...                      251.0  498.0
# 1962     8054871.0            ...                      239.0  571.0
# 1963     7650931.0            ...                      269.0  719.0
# 1964     8076970.0            ...                      221.0  856.0
# 1965     7925503.0            ...                      207.0  760.0
#
# Country  Marshall Islands  Greenland  British Virgin Islands  Tuvalu  Nauru  \
# Year
# 1961                  0.0      430.0                   717.0   473.0  184.0
# 1962                  0.0      513.0                   708.0   474.0  184.0
# 1963                  0.0      458.0                   598.0   476.0  185.0
# 1964                  0.0      665.0                   403.0   513.0  191.0
# 1965                  0.0      548.0                   409.0   514.0  212.0
#
# Country  Tokelau  Cayman Islands  Saint Pierre and Miquelon
# Year
# 1961       170.0             0.0                        0.0
# 1962       220.0             0.0                        0.0
# 1963       112.0             0.0                        0.0
# 1964       281.0             0.0                        0.0
# 1965       256.0             0.0                        0.0
#
# [5 rows x 220 columns]

# %% [markdown]
# **We drop the USSR here, as it itself is an aggregate of 15 countries, and was dissolved in 1991.**
#
# The [USSR](https://history.state.gov/milestones/1989-1992/collapse-soviet-union) disbanded in 1991.

# %%
del gap['USSR']

# %% [markdown]
# These aggregates represent the values of the PIN (Production Index Number) of the different countries.

# %% [markdown]
# # Comparison of countries which lead crop production vs those that trail it

# %% [markdown]
# We will be comparing the top five countries, along with the bottom 5. We will do this to see trends through time such as:
# + Yield through the years.
# + Which country has been leading.
# + Which country has the lowest.

# %% [markdown]
# ## Top 5 Countries

# %%
gap_top5 = gap.transpose()
gap_top5 = gap_top5.head(5)
gap_top5tran = gap_top5.transpose()
gap_top5tran
# Out:
# Country        China  United States of America        India      Brazil  \
# Year
# 1961      58340740.0                89816580.0   50142680.0  16564600.0
# 1962      60690860.0                90275010.0   50015760.0  17344940.0
# 1963      63942700.0                93700380.0   51367730.0  17443010.0
# 1964      68462610.0                94323650.0   52267720.0  17658130.0
# 1965      74747900.0                97704050.0   49498330.0  20367240.0
# 1966      80445930.0                97277180.0   49309560.0  19238750.0
# 1967      81718660.0               101177900.0   52731470.0  20650260.0
# 1968      81474800.0               103420600.0   55208160.0  21256810.0
# 1969      82195340.0               104285200.0   56970870.0  22008700.0
# 1970      86542200.0               102786400.0   60053830.0  22533890.0
# 1971      90085190.0               111234700.0   61559940.0  23583120.0
# 1972      88668910.0               111439800.0   58725260.0  24726620.0
# 1973      98613730.0               113008600.0   63310020.0  24599650.0
# 1974      98786610.0               110119400.0   61161410.0  26386030.0
# 1975     100902900.0               117511000.0   67573710.0  27173810.0
# 1976     100068700.0               120877500.0   66914630.0  28353660.0
# 1977     102256200.0               126192700.0   72476440.0  30125560.0
# 1978     112352200.0               126211800.0   75273500.0  29605350.0
# 1979     116862200.0               133091500.0   71872960.0  31451560.0
# 1980     117802300.0               127118400.0   74076420.0  34909200.0
# 1981     123609600.0               139390800.0   79854310.0  36180910.0
# 1982     134887200.0               139500900.0   79127070.0  36635890.0
# 1983     144335500.0               119197600.0   88341420.0  36707840.0
# 1984     157689000.0               136529200.0   90441380.0  38756650.0
# 1985     156197000.0               143144600.0   93183620.0  42469060.0
# 1986     160571200.0               136708300.0   93067530.0  40969750.0
# 1987     169315100.0               136752700.0   92052060.0  44823570.0
# 1988     174290700.0               126910100.0  102021900.0  46291220.0
# 1989     179084400.0               138218400.0  109289000.0  48140150.0
# 1990     192616000.0               144644000.0  109854700.0  45956520.0
# 1991     199926200.0               143249500.0  110870700.0  48781430.0
# 1992     209312400.0               155467400.0  115959300.0  51768700.0
# 1993     226179800.0               142796300.0  119014000.0  52008700.0
# 1994     236648000.0               164433800.0  123259200.0  55538480.0
# 1995     255004400.0               152325500.0  126802000.0  58603010.0
# 1996     271766600.0               162066800.0  132327200.0  57776820.0
# 1997     284542100.0               167072000.0  134052000.0  60006520.0
# 1998     295117400.0               167311700.0  137406600.0  60706480.0
# 1999     304490200.0               170083400.0  143567200.0  65353180.0
# 2000     315511100.0               173640200.0  142989200.0  67416260.0
# 2001     322771800.0               170755800.0  147351100.0  71250310.0
# 2002     336394800.0               167494400.0  137112300.0  75603330.0
# 2003     340623800.0               172458200.0  151552000.0  81198510.0
# 2004     360834700.0               183519100.0  149552600.0  85626940.0
# 2005     371939300.0               181432900.0  156869200.0  87363190.0
# 2006     380320200.0               176803000.0  164974800.0  85319580.0
# 2007     386448200.0               184698800.0  175747700.0  90075170.0
#
# Country      France
# Year
# 1961     23408500.0
# 1962     26654000.0
# 1963     25202710.0
# 1964     25321080.0
# 1965     26780910.0
# 1966     25447410.0
# 1967     27156150.0
# 1968     28165500.0
# 1969     26664590.0
# 1970     28293850.0
# 1971     28380690.0
# 1972     28244560.0
# 1973     30877850.0
# 1974     30775730.0
# 1975     29088000.0
# 1976     29122940.0
# 1977     28473830.0
# 1978     30657640.0
# 1979     32990410.0
# 1980     33203840.0
# 1981     32392090.0
# 1982     34577530.0
# 1983     33070830.0
# 1984     35548380.0
# 1985     34943830.0
# 1986     34515950.0
# 1987     35539910.0
# 1988     34906030.0
# 1989     34703740.0
# 1990     35135860.0
# 1991     34853330.0
# 1992     36502890.0
# 1993     34503340.0
# 1994     34601140.0
# 1995     35418700.0
# 1996     37320910.0
# 1997     37540180.0
# 1998     37902710.0
# 1999     38125640.0
# 2000     37449710.0
# 2001     35782140.0
# 2002     37868760.0
# 2003     34763540.0
# 2004     37570700.0
# 2005     36169630.0
# 2006     34776620.0
# 2007     34377050.0

# %% [markdown]
# From the above table, we concur that the top five countries are  Brazil, France, India, China and the United States.

# %%
gap_top5tran.fillna(0, inplace=True)
ax = gap_top5tran.plot(kind='area', figsize=(20,8), stacked=False)
ax.set_title('Top Gross Agricultural Producing Nations from 1961 to 2007', fontsize=20, fontweight='bold')
ax.set_ylabel('GAP in Billions (Int $)', fontsize=15)
ax.set_xlabel('Year')
ax.tick_params(labelsize=13)

# %% [markdown]
# ** It can clearly be seen how China has surpassed other nations, starting around 1984. The following [article](https://academic.oup.com/ajae/article-abstract/73/2/266/127074) explains how technology and institutional reform helped improve China's presence in the agricultural sector.**

# %%
gap_top5tran.fillna(0, inplace=True)
ax = gap_top5tran.plot(kind='bar', figsize=(20,8), stacked=False)
ax.set_title('Top Gross Agricultural Producing Nations from 1961 to 2007', fontsize=20, fontweight='bold')
ax.set_ylabel('GAP in Billions (Int $)', fontsize=15)
ax.set_xlabel('Year')
ax.tick_params(labelsize=13)

# %%
ax0 = gap_top5tran.plot(kind='box', figsize=(20,8))
ax0.set_title('Top Gross Agricultural Producing Nations from 1961 to 2007', fontsize=20, fontweight='bold')
ax0.set_ylabel('GAP in Billions (Int $)', fontsize=15)
ax0.tick_params(labelsize=10)

# %% [markdown]
# ## Trailing 5 Countries

# %% [markdown]
# We would should count the number of zero values in each column. The production being equal to zero is due to it not being recorded.
# https://stackoverflow.com/questions/29229600/counting-number-of-zeros-per-row-by-pandas-dataframe

# %%
gap_bottom5 = gap.transpose()
gap_bottom5 = gap_bottom5.tail(5)
gap_bottom5tran = gap_bottom5.transpose()
gap_bottom5tran
# Out:
# Country  Tuvalu  Nauru  Tokelau  Cayman Islands  Saint Pierre and Miquelon
# Year
# 1961      473.0  184.0    170.0             0.0                        0.0
# 1962      474.0  184.0    220.0             0.0                        0.0
# 1963      476.0  185.0    112.0             0.0                        0.0
# 1964      513.0  191.0    281.0             0.0                        0.0
# 1965      514.0  212.0    256.0             0.0                        0.0
# 1966      515.0  213.0    205.0           200.0                        0.0
# 1967      467.0  218.0    184.0           202.0                        0.0
# 1968      438.0  219.0    198.0           202.0                        0.0
# 1969      400.0  233.0    198.0           206.0                        0.0
# 1970      367.0  238.0    202.0           207.0                       27.0
# 1971      483.0  244.0    207.0           208.0                       10.0
# 1972      245.0  246.0    195.0           209.0                       16.0
# 1973      229.0  254.0    201.0           210.0                        0.0
# 1974      561.0  264.0    302.0           205.0                        5.0
# 1975      269.0  276.0    331.0           211.0                        0.0
# 1976      220.0  188.0    193.0           213.0                        2.0
# 1977      312.0  235.0    148.0           215.0                        0.0
# 1978      599.0  252.0    133.0           212.0                        1.0
# 1979      623.0  268.0    180.0           217.0                        1.0
# 1980      602.0  286.0    199.0           230.0                        1.0
# 1981      604.0  308.0    218.0           220.0                        0.0
# 1982      404.0  317.0    241.0           227.0                        0.0
# 1983      421.0  311.0    251.0           256.0                        1.0
# 1984      448.0  281.0    251.0           203.0                        1.0
# 1985      471.0  297.0    261.0           205.0                        9.0
# 1986      435.0  306.0    271.0           165.0                       12.0
# 1987      391.0  315.0    290.0           192.0                       14.0
# 1988      369.0  323.0    299.0           139.0                       17.0
# 1989      387.0  324.0    309.0           196.0                       17.0
# 1990      359.0  331.0    319.0           121.0                       21.0
# 1991      554.0  337.0    328.0           106.0                       21.0
# 1992      592.0  343.0    337.0           131.0                       22.0
# 1993      430.0  349.0    346.0           125.0                       19.0
# 1994      414.0  349.0    346.0           125.0                       19.0
# 1995      415.0  349.0    346.0           125.0                       19.0
# 1996      434.0  349.0    346.0           125.0                       21.0
# 1997      457.0  349.0    346.0           125.0                       21.0
# 1998      466.0  349.0    346.0           125.0                       21.0
# 1999      480.0  349.0    346.0           125.0                       21.0
# 2000      482.0  349.0    346.0           125.0                       25.0
# 2001      500.0  349.0    346.0           125.0                       26.0
# 2002      511.0  349.0    346.0           125.0                       28.0
# 2003      528.0  349.0    346.0           125.0                       25.0
# 2004      541.0  349.0    346.0           125.0                       26.0
# 2005      541.0  349.0    346.0           125.0                       24.0
# 2006      541.0  349.0    346.0           127.0                       26.0
# 2007      558.0  379.0    346.0           129.0                       23.0

# %%
gap_bottom5tran.describe()
# Out:
# Country      Tuvalu       Nauru     Tokelau  Cayman Islands  \
# count     47.000000   47.000000   47.000000       47.000000
# mean     457.723404  290.382979  269.787234      152.957447
# std       97.817199   59.193696   72.264591       67.704267
# min      220.000000  184.000000  112.000000        0.000000
# 25%      409.000000  241.000000  201.500000      125.000000
# 50%      471.000000  308.000000  281.000000      139.000000
# 75%      521.500000  349.000000  346.000000      207.500000
# max      623.000000  379.000000  346.000000      256.000000
#
# Country  Saint Pierre and Miquelon
# count                    47.000000
# mean                     11.531915
# std                      10.680846
# min                       0.000000
# 25%                       0.000000
# 50%                      12.000000
# 75%                      21.000000
# max                      28.000000

# %% [markdown]
# Our bottom 5 countries are Tuvalu, Nauru, Tokelau, Cayman Islands,and Saint Pierre and Miquelon.

# %%
gap_bottom5tran.fillna(0, inplace=True)
ax = gap_bottom5tran.plot(kind='area', figsize=(20,8), stacked=False)
ax.set_title('Nations Trailing Agricultural Production from 1961 to 2007', fontsize=20, fontweight='bold')
ax.set_ylabel('GAP in Billions (Int $)', fontsize=15)
ax.set_xlabel('Year')
ax.tick_params(labelsize=13)

# %% [markdown]
# This plot shows us how inconsistent the production in the bottom 5 countries have been. However, there is an overall trend of increasing production in them. This might be accounted for an increase in population, better technology, or changes in policies. A study comparing these factors would be of interest.
#
# **This is where we realize that the dataset for the trailing countries have not been consistently recorded. However, even the years that are recorded are in the mere millions.**

# %%
gap_bottom5tran.fillna(0, inplace=True)
ax = gap_bottom5tran.plot(kind='bar', figsize=(20,8), stacked=False)
ax.set_title('Trailing Agricultural Production in  Nations from 1961 to 2007', fontsize=20, fontweight='bold')
ax.set_ylabel('GAP in Billions (Int $)', fontsize=15)
ax.set_xlabel('Year')
ax.tick_params(labelsize=13)

# %%
ax0 = gap_bottom5tran.plot(kind='box', figsize=(20,8))
ax0.set_title('Trailing Gross Agricultural Producing Nations from 1961 to 2007', fontsize=20, fontweight='bold')
ax0.set_ylabel('GAP in Billions (Int $)', fontsize=15)
ax0.tick_params(labelsize=10)

# %% [markdown]
# # Random Sampling of Top 5 and Bottom 5 Countries

# %% [markdown]
# Here, we take samples from China and Tuvalu to perform a t-test and gather results from it.

# %%
fig, ax =plt.subplots(1,2)
sns.distplot(gap_top5tran.China, ax=ax[0])
sns.distplot(gap_bottom5tran.Tuvalu, ax=ax[1])
fig.show()
# Out:
# C:\Users\nairj\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
sample1 = np.random.choice(gap_top5tran.China, 100, replace=True)
plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample2 = np.random.choice(gap_bottom5tran.Tuvalu, 100, replace=True)
plt.hist(sample2, alpha=0.5, label='sample 2', color="orange") 
plt.legend(loc='upper right') 
plt.show()

# %% [markdown]
# ## t-test
# Now, running the t-test:

# %%
from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# Ttest_indResult(statistic=-17.600597954881128, pvalue=2.9993687961996463e-32)

# %% [markdown]
# We see that t-statistic and p-value are small, meaning there is very unlikely for us to have taken both samples from the same population (this makes sense, as the agriculture production of the bottom five vs the top five countries is worlds apart).

# %% [markdown]
# # Conclusion

# %% [markdown]
# The purpose of this capstone was to evaulate the agricultural trends of the top 5 and bottom 5 countries found in the FAO dataset. The objective was to evaluate the production through time, and see how these countries compare. Some missing data may account for the low values in the bottom five countries. We see an overall increase in production through time, and
#
# + technology
# + population increase
# + policies and educational reform
#
#
# Future studies could include:
# + forecasting of how these countries continue to grow
# + Which crops are grown the most.
# + Factors for high PIN.
