# %%
import numpy as np
import pandas as pd
import scipy as scipy
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.cbook as cbook
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv("fao_data_production_indices_data.csv", low_memory=False)
df
# Out:
#        country_or_area                                       element_code  \
# 0          Afghanistan                                                152
# 1          Afghanistan                                                152
# 2          Afghanistan                                                152
# 3          Afghanistan                                                152
# 4          Afghanistan                                                152
# 5          Afghanistan                                                152
# 6          Afghanistan                                                152
# 7          Afghanistan                                                152
# 8          Afghanistan                                                152
# 9          Afghanistan                                                152
# 10         Afghanistan                                                152
# 11         Afghanistan                                                152
# ...

# %%
del df['element_code']
del df['value_footnotes']
df.head()
# Out:
#   country_or_area                               element    year         unit  \
# 0     Afghanistan  Gross Production 1999-2001 (1000 I$)  2007.0  1000 Int. $
# 1     Afghanistan  Gross Production 1999-2001 (1000 I$)  2006.0  1000 Int. $
# 2     Afghanistan  Gross Production 1999-2001 (1000 I$)  2005.0  1000 Int. $
# 3     Afghanistan  Gross Production 1999-2001 (1000 I$)  2004.0  1000 Int. $
# 4     Afghanistan  Gross Production 1999-2001 (1000 I$)  2003.0  1000 Int. $
#
#        value         category
# 0  2486910.0  agriculture_pin
# 1  2278516.0  agriculture_pin
# 2  2524097.0  agriculture_pin
# 3  2226346.0  agriculture_pin
# 4  2289434.0  agriculture_pin

# %%
df.describe()
# Out:
#                 year         value
# count  311624.000000  3.116240e+05
# mean     1984.575219  4.021553e+06
# std        13.661817  3.617312e+07
# min      1961.000000  0.000000e+00
# 25%      1973.000000  8.400000e+01
# 50%      1985.000000  1.080000e+02
# 75%      1997.000000  2.813400e+04
# max      2007.000000  1.692538e+09

# %%
headers = ["Country", "Production", "Year", "Unit", "Price", "Category"]
df.columns = headers
df.head()
# Out:
#        Country                            Production    Year         Unit  \
# 0  Afghanistan  Gross Production 1999-2001 (1000 I$)  2007.0  1000 Int. $
# 1  Afghanistan  Gross Production 1999-2001 (1000 I$)  2006.0  1000 Int. $
# 2  Afghanistan  Gross Production 1999-2001 (1000 I$)  2005.0  1000 Int. $
# 3  Afghanistan  Gross Production 1999-2001 (1000 I$)  2004.0  1000 Int. $
# 4  Afghanistan  Gross Production 1999-2001 (1000 I$)  2003.0  1000 Int. $
#
#        Price         Category
# 0  2486910.0  agriculture_pin
# 1  2278516.0  agriculture_pin
# 2  2524097.0  agriculture_pin
# 3  2226346.0  agriculture_pin
# 4  2289434.0  agriculture_pin

# %%
df.shape
# Out:
# (311634, 6)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (311624, 6)

# %%
df.dtypes
#Change dtypes
# Out:
# Country        object
# Production     object
# Year          float64
# Unit           object
# Price         float64
# Category       object
# dtype: object

# %%
df[["Price"]]= df[["Price"]].astype("int")
df[["Year"]]=df[["Year"]].astype("object")
df.dtypes
# Out:
# Country       object
# Production    object
# Year          object
# Unit          object
# Price          int32
# Category      object
# dtype: object

# %%
Country= df.groupby('Country').sum()
Country.sort_values
# Out:
# <bound method DataFrame.sort_values of                                           Price
# Country
# Afghanistan                        5.137305e+08
# Africa +                           2.113607e+10
# Albania                            1.494898e+08
# Algeria                            6.302403e+08
# American Samoa                     6.042080e+05
# Americas +                         7.127633e+10
# Angola                             2.221367e+08
# Antigua and Barbuda                1.443409e+06
# Argentina                          5.393473e+09
# Armenia                            5.125982e+07
# Asia +                             1.180869e+11
# Australia                          3.732254e+09
# Australia and New Zealand +        5.300220e+09
# Austria                            8.952169e+08
# Azerbaijan                         1.304907e+08
# Bahamas                            3.921381e+06
# Bahrain                            4.454597e+06
# Bangladesh                         2.325624e+09
# ...

# %%
countries= country_group_pivot.transpose()
countries['Country']=countries.sum(axis=1)
countries.sort_values(["Country"], ascending=False, axis=0, inplace=True)
countries.head(10)
# Out:
# Country       World +        Asia +      Europe +    Americas +  \
# Year
# Total    1.964574e+10  7.872463e+09  5.233361e+09  4.751756e+09
# 2007.0   3.274174e+08  1.647531e+08  5.321021e+07  7.942430e+07
# 2006.0   3.218624e+08  1.608101e+08  5.364351e+07  7.635452e+07
# 2005.0   3.190695e+08  1.562121e+08  5.475476e+07  7.740991e+07
# 2004.0   3.131392e+08  1.504643e+08  5.667687e+07  7.638919e+07
# 2003.0   2.991637e+08  1.449716e+08  5.260609e+07  7.255947e+07
# 2002.0   2.912835e+08  1.399298e+08  5.452504e+07  6.945101e+07
# 2001.0   2.881070e+08  1.374879e+08  5.404857e+07  6.923312e+07
# 2000.0   2.838971e+08  1.346579e+08  5.373484e+07  6.889354e+07
# 1999.0   2.788817e+08  1.313312e+08  5.364479e+07  6.757825e+07
#
# Country  Eastern Asia +  European Union +         China  Northern America +  \
# Year
# Total      3.688186e+09      3.366661e+09  3.243825e+09        2.702104e+09
# 2007.0     8.038690e+07      3.904096e+07  7.507416e+07        3.961115e+07
# ...

# %%
country_group_pivot= country_group.pivot_table(index="Country", columns="Year", values="Price")
pivot= country_group_pivot
pivot
# Out:
# Year                                     1961.0        1962.0        1963.0  \
# Country
# Afghanistan                        2.664400e+05  2.721321e+05  2.732199e+05
# Africa +                           7.884130e+06  8.318992e+06  8.617131e+06
# Albania                            4.936077e+04  5.350023e+04  5.324857e+04
# Algeria                            3.240078e+05  3.436904e+05  3.446311e+05
# American Samoa                     4.913000e+02  4.971000e+02  5.970333e+02
# Americas +                         2.886614e+07  2.971729e+07  3.093183e+07
# Angola                             1.203303e+05  1.271995e+05  1.256248e+05
# Antigua and Barbuda                1.382433e+03  1.347167e+03  1.653433e+03
# Argentina                          2.337036e+06  2.458784e+06  2.695578e+06
# Armenia                                     NaN           NaN           NaN
# Asia +                             3.468189e+07  3.573116e+07  3.699557e+07
# ...

# %%
BRIC = pivot.loc[["China", "India", "USSR","Brazil"]]
BRIC
# Out:
# Year           1961.0        1962.0        1963.0        1964.0        1965.0  \
# Country
# China    1.110069e+07  1.152910e+07  1.211244e+07  1.297335e+07  1.419812e+07
# India    9.796515e+06  9.773863e+06  1.003771e+07  1.022222e+07  9.672228e+06
# USSR     2.518798e+07  2.550455e+07  2.440049e+07  2.805775e+07  2.740147e+07
# Brazil   3.178510e+06  3.319528e+06  3.324833e+06  3.367377e+06  3.902351e+06
#
# Year           1966.0        1967.0        1968.0        1969.0        1970.0  \
# Country
# China    1.525521e+07  1.549784e+07  1.545029e+07  1.558773e+07  1.635156e+07
# India    9.647586e+06  1.032222e+07  1.078696e+07  1.114432e+07  1.174499e+07
# USSR     3.103092e+07  3.163829e+07  3.360565e+07  3.170727e+07  3.409329e+07
# Brazil   3.671630e+06  3.947808e+06  4.050485e+06  4.201643e+06  4.310970e+06
#
# Year         ...             1998.0        1999.0        2000.0        2001.0  \
# Country      ...
# ...

# %%
bricc= BRIC.transpose()
bricc
# Out:
# Country         China         India          USSR        Brazil
# Year
# 1961.0   1.110069e+07  9.796515e+06  2.518798e+07  3.178510e+06
# 1962.0   1.152910e+07  9.773863e+06  2.550455e+07  3.319528e+06
# 1963.0   1.211244e+07  1.003771e+07  2.440049e+07  3.324833e+06
# 1964.0   1.297335e+07  1.022222e+07  2.805775e+07  3.367377e+06
# 1965.0   1.419812e+07  9.672228e+06  2.740147e+07  3.902351e+06
# 1966.0   1.525521e+07  9.647586e+06  3.103092e+07  3.671630e+06
# 1967.0   1.549784e+07  1.032222e+07  3.163829e+07  3.947808e+06
# 1968.0   1.545029e+07  1.078696e+07  3.360565e+07  4.050485e+06
# 1969.0   1.558773e+07  1.114432e+07  3.170727e+07  4.201643e+06
# 1970.0   1.635156e+07  1.174499e+07  3.409329e+07  4.310970e+06
# 1971.0   1.704431e+07  1.203211e+07  3.438640e+07  4.518741e+06
# 1972.0   1.679711e+07  1.147836e+07  3.250834e+07  4.738071e+06
# 1973.0   1.864062e+07  1.239274e+07  3.833611e+07  4.720655e+06
# 1974.0   1.865966e+07  1.197886e+07  3.626257e+07  5.072064e+06
# ...
